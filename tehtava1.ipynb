# %%
import pandas as pd

# %% [markdown]
# Mistä data kertoo:
#
# Miksi se sopii kNN:lle:
#
# Y-muuttuja: Quality - kertoo viinin laadun asteikolla 0-10. Tätä halutaan koittaa ennustaa muiden ominaisuuksien perusteella.
